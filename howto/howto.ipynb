# %% [markdown]
# # Initializing

# %%
# %load_ext autoreload
# %autoreload 2

import sys
import os
import re
import shutil
import random
import pprint
import itertools
import functools
import collections

import pysam
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
PROJECT_PATH = '/home/users/pjh/scripts/python_genome_packages'
sys.path.append(PROJECT_PATH)

import handygenome.common

from handygenome.common import ChromDict, Vcfspec, Interval
from handygenome.variantplus.breakends import Breakends
from handygenome.variantplus.variantplus import VariantPlus, VariantPlusList
from handygenome.variantplus.vcfplus import VcfPlus
from handygenome.igvhandle import IGVHandle

from handygenome.variantplus import vpfilter as libvpfilter

# %% [markdown]
# # Loading vcf

# %%
vcf_path = '/home/users/pjh/practice/pipeline_test/handygenome/filtered_mutect2_output/LU-87.snv.filtered.clean.annot.vcf.gz'

# vcfp: shorthand for VcfPlus
vcfp = VcfPlus(vcf_path)

# %% [markdown]
# # VcfPlus object

# %%
vcfp
# Out:
# <VcfPlus object>
# - refver: hg19
# - vplist:
#     [<VariantPlus object (1	813227	.	G	T)>,
#      <VariantPlus object (1	3679492	.	A	T)>,
#      <VariantPlus object (1	4394080	.	T	C)>,
#      <VariantPlus object (1	4923985	.	A	G)>,
#      <VariantPlus object (1	5359197	.	A	G)>,
#      <VariantPlus object (1	6016996	.	C	T)>,
#      <VariantPlus object (1	7260937	.	T	G)>,
#      <VariantPlus object (1	9319114	.	G	C)>,
#      <VariantPlus object (1	14248637	.	C	A)>,
#      <VariantPlus object (1	14421214	.	G	A)>,
#      <VariantPlus object (1	16050377	.	C	T)>,
#      <VariantPlus object (1	16666963	.	C	T)>,
#      <VariantPlus object (1	19398033	.	T	A)>,
#      <VariantPlus object (1	21582674	.	C	A)>,
#      <VariantPlus object (1	21760630	.	G	T)>,
#      <VariantPlus object (1	23445427	.	C	T)>,
#      <VariantPlus object (1	25667676	.	C	A)>,
#      <VariantPlus object (1	28498132	.	G	A)>,
#      <VariantPlus object (1	30152796	.	C	T)>,
#      <VariantPlus object (1	30401429	.	A	G)>,
#      <VariantPlus object (1	32110307	.	C	T)>,
#      <VariantPlus object (1	33321097	.	C	T)>,
#      <VariantPlus object (1	34283801	.	C	T)>,
#      <VariantPlus object (1	34983222	.	T	G)>,
#      <VariantPlus object (1	36994284	.	A	C)>,
#      <VariantPlus object (1	37656250	.	G	C)>,
#      <VariantPlus object (1	37929649	.	G	T)>,
#      <VariantPlus object (1	38093821	.	C	T)>,
#      <VariantPlus object (1	39313821	.	C	G)>,
#      <VariantPlus object (1	41926557	.	C	T)>]
#     ...
#     2695 VariantPlus objects

# %%
vcfp.refver
# Out:
# 'hg19'

# %%
vcfp.length
# Out:
# 2695

# %% [markdown]
# # Filtering

# %%
filt = vpfilters.get_genename_filter(['TP53', 'EGFR'])

# %%
vcfp.filter_vplist(filt)

# %%
vcfp.vplist_filtered
# Out:
# [<VariantPlus object (7	55122265	.	G	C)>,
#  <VariantPlus object (7	55259515	.	T	G)>]

# %%
vcfp.vplist_filtered[1].annotdb.cosmic['max_occur_count']
# Out:
# 2647

# %%
vcfp.vplist_filtered[1].annotdb.transcript_canonical
# Out:
# {'ENST00000275493': {'aa_change': ['L', 'R'],
#                      'biotype': 'protein_coding',
#                      'ccds_id': 'CCDS5514.1',
#                      'chrom': 7,
#                      'codon_change': ['cTg', 'cGg'],
#                      'codon_frame0': 1,
#                      'consequence_flags': {'is_3pUTR_involved': False,
#                                            'is_5pUTR_involved': False,
#                                            'is_SV_consequence': False,
#                                            'is_frameshift': False,
#                                            'is_missense': True,
#                                            'is_not_protein_altering': False,
#                                            'is_protein_altering': True,
#                                            'is_splice_acceptor_involved': False,
#                                            'is_splice_donor_involved': False,
#                                            'is_splice_region_involved': False,
#                                            'is_startlost': False,
#                                            'is_stopgain': False,
#                                            'is_stoplost': False,
#                                            'is_synonymous': False,
#                                            'is_unclassified': False},
#                      'consequences': ['missense_variant'],
#                      'distance': None,
#                      'end0': 55279321,
#                      'end1': 55279321,
#                      'feature_type': 'transcript',
#                      'feature_type_flags': {'is_motif': False,
#                                             'is_regulatory': False,
#                                             'is_repeat': False,
#                                             'is_transcript': True},
#                      'gene_id': 'ENSG00000146648',
#                      'gene_name': 'EGFR',
#                      'hgvsc': 'ENST00000275493.2:c.2573T>G',
#                      'hgvsp': 'ENSP00000275493.2:p.Leu858Arg',
#                      'id': 'ENST00000275493',
#                      'involved_exons': [21],
#                      'involved_introns': None,
#                      'is_canonical': True,
#                      'is_exon_involved': True,
#                      'is_forward': True,
#                      'is_intron_involved': False,
#                      'mane_select': None,
#                      'polyphen_prediction': 'probably_damaging',
#                      'polyphen_score': 0.999,
#                      'protein_id': 'ENSP00000275493',
#                      'refseq_id': 'NM_005228.3',
#                      'sift_prediction': 'deleterious',
#                      'sift_score': 0.0,
#                      'start0': 55086793,
#                      'start1': 55086794,
#                      'transcript_name': 'EGFR-001',
#                      'transcript_subtype_flags': {'is_IG': False,
#                                                   'is_IG_pseudogene': False,
#                                                   'is_NMD': False,
#                                                   'is_NSD': False,
#                                                   'is_TR': False,
#                                                   'is_TR_pseudogene': False,
#                                                   'is_antisense': False,
#                                                   'is_coding': True,
#                                                   'is_lncRNA': False,
#                                                   'is_miRNA': False,
#                                                   'is_noncoding': False,
#                                                   'is_processed_pseudogene': False,
#                                                   'is_pseudogene': False,
#                                                   'is_rRNA': False,
#                                                   'is_tRNA': False,
#                                                   'is_transcribed_pseudogene': False,
#                                                   'is_translated_pseudogene': False,
#                                                   'is_unitary_pseudogene': False,
#                                                   'is_unknown_type': False,
#                                                   'is_unprocessed_pseudogene': False},
#                      'variant_pos_cds': 2573,
#                      'variant_pos_protein': 858,
#                      'variant_pos_transcript': 2750},
#  'ENST00000442411': {'aa_change': None,
#                      'biotype': 'antisense',
#                      'ccds_id': None,
#                      'chrom': 7,
#                      'codon_change': None,
#                      'codon_frame0': None,
#                      'consequence_flags': {'is_3pUTR_involved': False,
#                                            'is_5pUTR_involved': False,
#                                            'is_SV_consequence': False,
#                                            'is_frameshift': False,
#                                            'is_missense': False,
#                                            'is_not_protein_altering': True,
#                                            'is_protein_altering': False,
#                                            'is_splice_acceptor_involved': False,
#                                            'is_splice_donor_involved': False,
#                                            'is_splice_region_involved': False,
#                                            'is_startlost': False,
#                                            'is_stopgain': False,
#                                            'is_stoplost': False,
#                                            'is_synonymous': False,
#                                            'is_unclassified': False},
#                      'consequences': ['upstream_gene_variant'],
#                      'distance': -2888,
#                      'end0': 55256627,
#                      'end1': 55256627,
#                      'feature_type': 'transcript',
#                      'feature_type_flags': {'is_motif': False,
#                                             'is_regulatory': False,
#                                             'is_repeat': False,
#                                             'is_transcript': True},
#                      'gene_id': 'ENSG00000224057',
#                      'gene_name': 'EGFR-AS1',
#                      'hgvsc': None,
#                      'hgvsp': None,
#                      'id': 'ENST00000442411',
#                      'involved_exons': None,
#                      'involved_introns': None,
#                      'is_canonical': True,
#                      'is_exon_involved': False,
#                      'is_forward': False,
#                      'is_intron_involved': False,
#                      'mane_select': None,
#                      'polyphen_prediction': None,
#                      'polyphen_score': None,
#                      'protein_id': None,
#                      'refseq_id': None,
#                      'sift_prediction': None,
#                      'sift_score': None,
#                      'start0': 55247442,
#                      'start1': 55247443,
#                      'transcript_name': 'EGFR-AS1-001',
#                      'transcript_subtype_flags': {'is_IG': False,
#                                                   'is_IG_pseudogene': False,
#                                                   'is_NMD': False,
#                                                   'is_NSD': False,
#                                                   'is_TR': False,
#                                                   'is_TR_pseudogene': False,
#                                                   'is_antisense': True,
#                                                   'is_coding': False,
#                                                   'is_lncRNA': False,
#                                                   'is_miRNA': False,
#                                                   'is_noncoding': True,
#                                                   'is_processed_pseudogene': False,
#                                                   'is_pseudogene': False,
#                                                   'is_rRNA': False,
#                                                   'is_tRNA': False,
#                                                   'is_transcribed_pseudogene': False,
#                                                   'is_translated_pseudogene': False,
#                                                   'is_unitary_pseudogene': False,
#                                                   'is_unknown_type': False,
#                                                   'is_unprocessed_pseudogene': False},
#                      'variant_pos_cds': None,
#                      'variant_pos_protein': None,
#                      'variant_pos_transcript': None}}

# %% [markdown]
# # VariantPlus object

# %%
vp = vcfp.vplist_filtered[1]

# %%
vp.get_gene_names()
# Out:
# ['EGFR']

# %%
vp.annotdb.transcript_canon_ovlp
# Out:
# {'ENST00000275493': {'aa_change': ['L', 'R'],
#                      'biotype': 'protein_coding',
#                      'ccds_id': 'CCDS5514.1',
#                      'chrom': 7,
#                      'codon_change': ['cTg', 'cGg'],
#                      'codon_frame0': 1,
#                      'consequence_flags': {'is_3pUTR_involved': False,
#                                            'is_5pUTR_involved': False,
#                                            'is_SV_consequence': False,
#                                            'is_frameshift': False,
#                                            'is_missense': True,
#                                            'is_not_protein_altering': False,
#                                            'is_protein_altering': True,
#                                            'is_splice_acceptor_involved': False,
#                                            'is_splice_donor_involved': False,
#                                            'is_splice_region_involved': False,
#                                            'is_startlost': False,
#                                            'is_stopgain': False,
#                                            'is_stoplost': False,
#                                            'is_synonymous': False,
#                                            'is_unclassified': False},
#                      'consequences': ['missense_variant'],
#                      'distance': None,
#                      'end0': 55279321,
#                      'end1': 55279321,
#                      'feature_type': 'transcript',
#                      'feature_type_flags': {'is_motif': False,
#                                             'is_regulatory': False,
#                                             'is_repeat': False,
#                                             'is_transcript': True},
#                      'gene_id': 'ENSG00000146648',
#                      'gene_name': 'EGFR',
#                      'hgvsc': 'ENST00000275493.2:c.2573T>G',
#                      'hgvsp': 'ENSP00000275493.2:p.Leu858Arg',
#                      'id': 'ENST00000275493',
#                      'involved_exons': [21],
#                      'involved_introns': None,
#                      'is_canonical': True,
#                      'is_exon_involved': True,
#                      'is_forward': True,
#                      'is_intron_involved': False,
#                      'mane_select': None,
#                      'polyphen_prediction': 'probably_damaging',
#                      'polyphen_score': 0.999,
#                      'protein_id': 'ENSP00000275493',
#                      'refseq_id': 'NM_005228.3',
#                      'sift_prediction': 'deleterious',
#                      'sift_score': 0.0,
#                      'start0': 55086793,
#                      'start1': 55086794,
#                      'transcript_name': 'EGFR-001',
#                      'transcript_subtype_flags': {'is_IG': False,
#                                                   'is_IG_pseudogene': False,
#                                                   'is_NMD': False,
#                                                   'is_NSD': False,
#                                                   'is_TR': False,
#                                                   'is_TR_pseudogene': False,
#                                                   'is_antisense': False,
#                                                   'is_coding': True,
#                                                   'is_lncRNA': False,
#                                                   'is_miRNA': False,
#                                                   'is_noncoding': False,
#                                                   'is_processed_pseudogene': False,
#                                                   'is_pseudogene': False,
#                                                   'is_rRNA': False,
#                                                   'is_tRNA': False,
#                                                   'is_transcribed_pseudogene': False,
#                                                   'is_translated_pseudogene': False,
#                                                   'is_unitary_pseudogene': False,
#                                                   'is_unknown_type': False,
#                                                   'is_unprocessed_pseudogene': False},
#                      'variant_pos_cds': 2573,
#                      'variant_pos_protein': 858,
#                      'variant_pos_transcript': 2750}}

# %%
vp.annotdb.regulatory
# Out:
# {'ENSR00001397155': {'activity': {'A549': 'ACTIVE',
#                                   'A673': 'ACTIVE',
#                                   'B': 'REPRESSED',
#                                   'B_PB': 'NA',
#                                   'CD14_monocyte_1': 'REPRESSED',
#                                   'CD14_monocyte_PB': 'NA',
#                                   'CD4_CD25_ab_Treg_PB': 'NA',
#                                   'CD4_ab_T': 'NA',
#                                   'CD4_ab_T_PB_1': 'NA',
#                                   'CD4_ab_T_PB_2': 'NA',
#                                   'CD4_ab_T_Th': 'NA',
#                                   'CD4_ab_T_VB': 'NA',
#                                   'CD8_ab_T_CB': 'NA',
#                                   'CD8_ab_T_PB': 'NA',
#                                   'CMP_CD4_1': 'NA',
#                                   'CMP_CD4_2': 'NA',
#                                   'CMP_CD4_3': 'NA',
#                                   'CM_CD4_ab_T_VB': 'NA',
#                                   'DND_41': 'REPRESSED',
#                                   'EB_CB': 'NA',
#                                   'EM_CD4_ab_T_PB': 'NA',
#                                   'EM_CD8_ab_T_VB': 'NA',
#                                   'EPC_VB': 'NA',
#                                   'GM12878': 'ACTIVE',
#                                   'H1_hESC_2': 'NA',
#                                   'H1_hESC_3': 'INACTIVE',
#                                   'H9_1': 'NA',
#                                   'HCT116': 'ACTIVE',
#                                   'HSMM': 'INACTIVE',
#                                   'HUES48': 'NA',
#                                   'HUES6': 'NA',
#                                   'HUES64': 'NA',
#                                   'HUVEC': 'INACTIVE',
#                                   'HUVEC_prol_CB': 'NA',
#                                   'HeLa_S3': 'INACTIVE',
#                                   'HepG2': 'INACTIVE',
#                                   'K562': 'REPRESSED',
#                                   'M0_CB': 'NA',
#                                   'M0_VB': 'NA',
#                                   'M1_CB': 'NA',
#                                   'M1_VB': 'NA',
#                                   'M2_CB': 'NA',
#                                   'M2_VB': 'NA',
#                                   'MCF_7': 'INACTIVE',
#                                   'MM_1S': 'INACTIVE',
#                                   'MSC': 'NA',
#                                   'MSC_VB': 'NA',
#                                   'NHLF': 'INACTIVE',
#                                   'NK_PB': 'NA',
#                                   'NPC_1': 'NA',
#                                   'NPC_2': 'ACTIVE',
#                                   'NPC_3': 'NA',
#                                   'PC_3': 'ACTIVE',
#                                   'PC_9': 'INACTIVE',
#                                   'SK_N_': 'ACTIVE',
#                                   'T_PB': 'NA',
#                                   'Th17': 'NA',
#                                   'UCSF_4': 'NA',
#                                   'adrenal_gland': 'NA',
#                                   'aorta': 'NA',
#                                   'astrocyte': 'INACTIVE',
#                                   'bipolar_neuron': 'INACTIVE',
#                                   'brain_1': 'NA',
#                                   'brain_2': 'NA',
#                                   'cardiac_muscle': 'ACTIVE',
#                                   'dermal_fibroblast': 'ACTIVE',
#                                   'endocrine_pancreas': 'NA',
#                                   'endodermal': 'NA',
#                                   'eosinophil_VB': 'NA',
#                                   'esophagus': 'NA',
#                                   'foreskin_fibroblast_1': 'NA',
#                                   'foreskin_fibroblast_2': 'NA',
#                                   'foreskin_keratinocyte_2': 'NA',
#                                   'foreskin_melanocyte_1': 'NA',
#                                   'foreskin_melanocyte_2': 'NA',
#                                   'germinal_matrix': 'NA',
#                                   'heart': 'NA',
#                                   'hepatocyte': 'INACTIVE',
#                                   'iPS_15b': 'NA',
#                                   'iPS_20b': 'NA',
#                                   'iPS_DF_19_11': 'NA',
#                                   'iPS_DF_6_9': 'NA',
#                                   'keratinocyte': 'INACTIVE',
#                                   'kidney': 'NA',
#                                   'large_intestine': 'NA',
#                                   'left_ventricle': 'NA',
#                                   'leg_muscle': 'NA',
#                                   'lung_1': 'NA',
#                                   'lung_2': 'NA',
#                                   'mammary_epithelial_1': 'INACTIVE',
#                                   'mammary_epithelial_2': 'NA',
#                                   'monocyte_CB': 'NA',
#                                   'monocyte_VB': 'NA',
#                                   'myotube': 'INACTIVE',
#                                   'naive_B_VB': 'NA',
#                                   'neuron': 'NA',
#                                   'neurosphere_C': 'NA',
#                                   'neurosphere_GE': 'NA',
#                                   'neutro_myelocyte': 'NA',
#                                   'neutrophil_CB': 'NA',
#                                   'neutrophil_VB': 'NA',
#                                   'osteoblast': 'INACTIVE',
#                                   'ovary': 'NA',
#                                   'pancreas': 'NA',
#                                   'placenta': 'NA',
#                                   'psoas_muscle': 'NA',
#                                   'right_atrium': 'NA',
#                                   'right_ventricle': 'NA',
#                                   'sigmoid_colon': 'NA',
#                                   'small_intestine_1': 'NA',
#                                   'small_intestine_2': 'NA',
#                                   'spleen': 'NA',
#                                   'stomach_1': 'NA',
#                                   'stomach_2': 'NA',
#                                   'thymus_1': 'NA',
#                                   'thymus_2': 'NA',
#                                   'trophoblast': 'NA',
#                                   'trunk_muscle': 'NA'},
#                      'bound_end0': 55257400,
#                      'bound_end1': 55257400,
#                      'bound_start0': 55257200,
#                      'bound_start1': 55257201,
#                      'chrom': 7,
#                      'distance': -2115,
#                      'end0': 55257400,
#                      'end1': 55257400,
#                      'feature_type': 'regulatory',
#                      'feature_type_flags': {'is_motif': False,
#                                             'is_regulatory': True,
#                                             'is_repeat': False,
#                                             'is_transcript': False},
#                      'id': 'ENSR00001397155',
#                      'regulatory_subtype_flags': {'is_CTCFBS': True,
#                                                   'is_TFBS': False,
#                                                   'is_enhancer': False,
#                                                   'is_open_chromatin': False,
#                                                   'is_promoter': False,
#                                                   'is_promoter_flank': False},
#                      'start0': 55257200,
#                      'start1': 55257201},
#  'ENSR00001397156': {'activity': {'A549': 'INACTIVE',
#                                   'A673': 'ACTIVE',
#                                   'B': 'REPRESSED',
#                                   'B_PB': 'NA',
#                                   'CD14_monocyte_1': 'REPRESSED',
#                                   'CD14_monocyte_PB': 'NA',
#                                   'CD4_CD25_ab_Treg_PB': 'NA',
#                                   'CD4_ab_T': 'NA',
#                                   'CD4_ab_T_PB_1': 'NA',
#                                   'CD4_ab_T_PB_2': 'NA',
#                                   'CD4_ab_T_Th': 'NA',
#                                   'CD4_ab_T_VB': 'NA',
#                                   'CD8_ab_T_CB': 'NA',
#                                   'CD8_ab_T_PB': 'NA',
#                                   'CMP_CD4_1': 'NA',
#                                   'CMP_CD4_2': 'NA',
#                                   'CMP_CD4_3': 'NA',
#                                   'CM_CD4_ab_T_VB': 'NA',
#                                   'DND_41': 'REPRESSED',
#                                   'EB_CB': 'NA',
#                                   'EM_CD4_ab_T_PB': 'NA',
#                                   'EM_CD8_ab_T_VB': 'NA',
#                                   'EPC_VB': 'NA',
#                                   'GM12878': 'INACTIVE',
#                                   'H1_hESC_2': 'NA',
#                                   'H1_hESC_3': 'INACTIVE',
#                                   'H9_1': 'NA',
#                                   'HCT116': 'INACTIVE',
#                                   'HSMM': 'INACTIVE',
#                                   'HUES48': 'NA',
#                                   'HUES6': 'NA',
#                                   'HUES64': 'NA',
#                                   'HUVEC': 'INACTIVE',
#                                   'HUVEC_prol_CB': 'NA',
#                                   'HeLa_S3': 'INACTIVE',
#                                   'HepG2': 'INACTIVE',
#                                   'K562': 'REPRESSED',
#                                   'M0_CB': 'NA',
#                                   'M0_VB': 'NA',
#                                   'M1_CB': 'NA',
#                                   'M1_VB': 'NA',
#                                   'M2_CB': 'NA',
#                                   'M2_VB': 'NA',
#                                   'MCF_7': 'ACTIVE',
#                                   'MM_1S': 'INACTIVE',
#                                   'MSC': 'NA',
#                                   'MSC_VB': 'NA',
#                                   'NHLF': 'INACTIVE',
#                                   'NK_PB': 'NA',
#                                   'NPC_1': 'NA',
#                                   'NPC_2': 'ACTIVE',
#                                   'NPC_3': 'NA',
#                                   'PC_3': 'INACTIVE',
#                                   'PC_9': 'INACTIVE',
#                                   'SK_N_': 'INACTIVE',
#                                   'T_PB': 'NA',
#                                   'Th17': 'NA',
#                                   'UCSF_4': 'NA',
#                                   'adrenal_gland': 'NA',
#                                   'aorta': 'NA',
#                                   'astrocyte': 'INACTIVE',
#                                   'bipolar_neuron': 'INACTIVE',
#                                   'brain_1': 'NA',
#                                   'brain_2': 'NA',
#                                   'cardiac_muscle': 'ACTIVE',
#                                   'dermal_fibroblast': 'INACTIVE',
#                                   'endocrine_pancreas': 'NA',
#                                   'endodermal': 'NA',
#                                   'eosinophil_VB': 'NA',
#                                   'esophagus': 'NA',
#                                   'foreskin_fibroblast_1': 'NA',
#                                   'foreskin_fibroblast_2': 'NA',
#                                   'foreskin_keratinocyte_2': 'NA',
#                                   'foreskin_melanocyte_1': 'NA',
#                                   'foreskin_melanocyte_2': 'NA',
#                                   'germinal_matrix': 'NA',
#                                   'heart': 'NA',
#                                   'hepatocyte': 'INACTIVE',
#                                   'iPS_15b': 'NA',
#                                   'iPS_20b': 'NA',
#                                   'iPS_DF_19_11': 'NA',
#                                   'iPS_DF_6_9': 'NA',
#                                   'keratinocyte': 'INACTIVE',
#                                   'kidney': 'NA',
#                                   'large_intestine': 'NA',
#                                   'left_ventricle': 'NA',
#                                   'leg_muscle': 'NA',
#                                   'lung_1': 'NA',
#                                   'lung_2': 'NA',
#                                   'mammary_epithelial_1': 'INACTIVE',
#                                   'mammary_epithelial_2': 'NA',
#                                   'monocyte_CB': 'NA',
#                                   'monocyte_VB': 'NA',
#                                   'myotube': 'INACTIVE',
#                                   'naive_B_VB': 'NA',
#                                   'neuron': 'NA',
#                                   'neurosphere_C': 'NA',
#                                   'neurosphere_GE': 'NA',
#                                   'neutro_myelocyte': 'NA',
#                                   'neutrophil_CB': 'NA',
#                                   'neutrophil_VB': 'NA',
#                                   'osteoblast': 'INACTIVE',
#                                   'ovary': 'NA',
#                                   'pancreas': 'NA',
#                                   'placenta': 'NA',
#                                   'psoas_muscle': 'NA',
#                                   'right_atrium': 'NA',
#                                   'right_ventricle': 'NA',
#                                   'sigmoid_colon': 'NA',
#                                   'small_intestine_1': 'NA',
#                                   'small_intestine_2': 'NA',
#                                   'spleen': 'NA',
#                                   'stomach_1': 'NA',
#                                   'stomach_2': 'NA',
#                                   'thymus_1': 'NA',
#                                   'thymus_2': 'NA',
#                                   'trophoblast': 'NA',
#                                   'trunk_muscle': 'NA'},
#                      'bound_end0': 55260600,
#                      'bound_end1': 55260600,
#                      'bound_start0': 55260200,
#                      'bound_start1': 55260201,
#                      'chrom': 7,
#                      'distance': 686,
#                      'end0': 55260600,
#                      'end1': 55260600,
#                      'feature_type': 'regulatory',
#                      'feature_type_flags': {'is_motif': False,
#                                             'is_regulatory': True,
#                                             'is_repeat': False,
#                                             'is_transcript': False},
#                      'id': 'ENSR00001397156',
#                      'regulatory_subtype_flags': {'is_CTCFBS': True,
#                                                   'is_TFBS': False,
#                                                   'is_enhancer': False,
#                                                   'is_open_chromatin': False,
#                                                   'is_promoter': False,
#                                                   'is_promoter_flank': False},
#                      'start0': 55260200,
#                      'start1': 55260201},
#  'ENSR00001726614': {'activity': {'A549': 'ACTIVE',
#                                   'A673': 'ACTIVE',
#                                   'B': 'REPRESSED',
#                                   'B_PB': 'INACTIVE',
#                                   'CD14_monocyte_1': 'REPRESSED',
#                                   'CD14_monocyte_PB': 'INACTIVE',
#                                   'CD4_CD25_ab_Treg_PB': 'INACTIVE',
#                                   'CD4_ab_T': 'INACTIVE',
#                                   'CD4_ab_T_PB_1': 'REPRESSED',
#                                   'CD4_ab_T_PB_2': 'INACTIVE',
#                                   'CD4_ab_T_Th': 'INACTIVE',
#                                   'CD4_ab_T_VB': 'INACTIVE',
#                                   'CD8_ab_T_CB': 'INACTIVE',
#                                   'CD8_ab_T_PB': 'INACTIVE',
#                                   'CMP_CD4_1': 'INACTIVE',
#                                   'CMP_CD4_2': 'INACTIVE',
#                                   'CMP_CD4_3': 'REPRESSED',
#                                   'CM_CD4_ab_T_VB': 'INACTIVE',
#                                   'DND_41': 'REPRESSED',
#                                   'EB_CB': 'INACTIVE',
#                                   'EM_CD4_ab_T_PB': 'INACTIVE',
#                                   'EM_CD8_ab_T_VB': 'INACTIVE',
#                                   'EPC_VB': 'ACTIVE',
#                                   'GM12878': 'INACTIVE',
#                                   'H1_hESC_2': 'INACTIVE',
#                                   'H1_hESC_3': 'ACTIVE',
#                                   'H9_1': 'INACTIVE',
#                                   'HCT116': 'ACTIVE',
#                                   'HSMM': 'ACTIVE',
#                                   'HUES48': 'ACTIVE',
#                                   'HUES6': 'INACTIVE',
#                                   'HUES64': 'INACTIVE',
#                                   'HUVEC': 'ACTIVE',
#                                   'HUVEC_prol_CB': 'ACTIVE',
#                                   'HeLa_S3': 'ACTIVE',
#                                   'HepG2': 'ACTIVE',
#                                   'K562': 'REPRESSED',
#                                   'M0_CB': 'INACTIVE',
#                                   'M0_VB': 'INACTIVE',
#                                   'M1_CB': 'INACTIVE',
#                                   'M1_VB': 'INACTIVE',
#                                   'M2_CB': 'INACTIVE',
#                                   'M2_VB': 'INACTIVE',
#                                   'MCF_7': 'ACTIVE',
#                                   'MM_1S': 'INACTIVE',
#                                   'MSC': 'ACTIVE',
#                                   'MSC_VB': 'INACTIVE',
#                                   'NHLF': 'ACTIVE',
#                                   'NK_PB': 'INACTIVE',
#                                   'NPC_1': 'INACTIVE',
#                                   'NPC_2': 'INACTIVE',
#                                   'NPC_3': 'POISED',
#                                   'PC_3': 'ACTIVE',
#                                   'PC_9': 'ACTIVE',
#                                   'SK_N_': 'ACTIVE',
#                                   'T_PB': 'REPRESSED',
#                                   'Th17': 'INACTIVE',
#                                   'UCSF_4': 'ACTIVE',
#                                   'adrenal_gland': 'ACTIVE',
#                                   'aorta': 'REPRESSED',
#                                   'astrocyte': 'ACTIVE',
#                                   'bipolar_neuron': 'ACTIVE',
#                                   'brain_1': 'INACTIVE',
#                                   'brain_2': 'INACTIVE',
#                                   'cardiac_muscle': 'INACTIVE',
#                                   'dermal_fibroblast': 'ACTIVE',
#                                   'endocrine_pancreas': 'INACTIVE',
#                                   'endodermal': 'ACTIVE',
#                                   'eosinophil_VB': 'INACTIVE',
#                                   'esophagus': 'ACTIVE',
#                                   'foreskin_fibroblast_1': 'ACTIVE',
#                                   'foreskin_fibroblast_2': 'INACTIVE',
#                                   'foreskin_keratinocyte_2': 'INACTIVE',
#                                   'foreskin_melanocyte_1': 'INACTIVE',
#                                   'foreskin_melanocyte_2': 'REPRESSED',
#                                   'germinal_matrix': 'INACTIVE',
#                                   'heart': 'INACTIVE',
#                                   'hepatocyte': 'ACTIVE',
#                                   'iPS_15b': 'INACTIVE',
#                                   'iPS_20b': 'ACTIVE',
#                                   'iPS_DF_19_11': 'ACTIVE',
#                                   'iPS_DF_6_9': 'ACTIVE',
#                                   'keratinocyte': 'ACTIVE',
#                                   'kidney': 'INACTIVE',
#                                   'large_intestine': 'ACTIVE',
#                                   'left_ventricle': 'ACTIVE',
#                                   'leg_muscle': 'INACTIVE',
#                                   'lung_1': 'ACTIVE',
#                                   'lung_2': 'ACTIVE',
#                                   'mammary_epithelial_1': 'ACTIVE',
#                                   'mammary_epithelial_2': 'ACTIVE',
#                                   'monocyte_CB': 'INACTIVE',
#                                   'monocyte_VB': 'INACTIVE',
#                                   'myotube': 'ACTIVE',
#                                   'naive_B_VB': 'INACTIVE',
#                                   'neuron': 'REPRESSED',
#                                   'neurosphere_C': 'ACTIVE',
#                                   'neurosphere_GE': 'INACTIVE',
#                                   'neutro_myelocyte': 'INACTIVE',
#                                   'neutrophil_CB': 'INACTIVE',
#                                   'neutrophil_VB': 'INACTIVE',
#                                   'osteoblast': 'ACTIVE',
#                                   'ovary': 'ACTIVE',
#                                   'pancreas': 'POISED',
#                                   'placenta': 'ACTIVE',
#                                   'psoas_muscle': 'ACTIVE',
#                                   'right_atrium': 'ACTIVE',
#                                   'right_ventricle': 'ACTIVE',
#                                   'sigmoid_colon': 'ACTIVE',
#                                   'small_intestine_1': 'ACTIVE',
#                                   'small_intestine_2': 'ACTIVE',
#                                   'spleen': 'INACTIVE',
#                                   'stomach_1': 'ACTIVE',
#                                   'stomach_2': 'ACTIVE',
#                                   'thymus_1': 'INACTIVE',
#                                   'thymus_2': 'INACTIVE',
#                                   'trophoblast': 'ACTIVE',
#                                   'trunk_muscle': 'REPRESSED'},
#                      'biotype': 'promoter_flanking_region',
#                      'bound_end0': 55261799,
#                      'bound_end1': 55261799,
#                      'bound_start0': 55252800,
#                      'bound_start1': 55252801,
#                      'chrom': 7,
#                      'consequences': ['regulatory_region_variant'],
#                      'distance': None,
#                      'end0': 55261799,
#                      'end1': 55261799,
#                      'feature_type': 'regulatory',
#                      'feature_type_flags': {'is_motif': False,
#                                             'is_regulatory': True,
#                                             'is_repeat': False,
#                                             'is_transcript': False},
#                      'id': 'ENSR00001726614',
#                      'is_forward': None,
#                      'regulatory_subtype_flags': {'is_CTCFBS': False,
#                                                   'is_TFBS': False,
#                                                   'is_enhancer': False,
#                                                   'is_open_chromatin': False,
#                                                   'is_promoter': False,
#                                                   'is_promoter_flank': True},
#                      'start0': 55252800,
#                      'start1': 55252801},
#  'ENSR00002050860': {'activity': {'A549': 'INACTIVE',
#                                   'A673': 'INACTIVE',
#                                   'B': 'REPRESSED',
#                                   'B_PB': 'INACTIVE',
#                                   'CD14_monocyte_1': 'REPRESSED',
#                                   'CD14_monocyte_PB': 'INACTIVE',
#                                   'CD4_CD25_ab_Treg_PB': 'INACTIVE',
#                                   'CD4_ab_T': 'INACTIVE',
#                                   'CD4_ab_T_PB_1': 'REPRESSED',
#                                   'CD4_ab_T_PB_2': 'INACTIVE',
#                                   'CD4_ab_T_Th': 'INACTIVE',
#                                   'CD4_ab_T_VB': 'INACTIVE',
#                                   'CD8_ab_T_CB': 'INACTIVE',
#                                   'CD8_ab_T_PB': 'INACTIVE',
#                                   'CMP_CD4_1': 'INACTIVE',
#                                   'CMP_CD4_2': 'INACTIVE',
#                                   'CMP_CD4_3': 'INACTIVE',
#                                   'CM_CD4_ab_T_VB': 'INACTIVE',
#                                   'DND_41': 'REPRESSED',
#                                   'EB_CB': 'INACTIVE',
#                                   'EM_CD4_ab_T_PB': 'INACTIVE',
#                                   'EM_CD8_ab_T_VB': 'INACTIVE',
#                                   'EPC_VB': 'ACTIVE',
#                                   'GM12878': 'INACTIVE',
#                                   'H1_hESC_2': 'ACTIVE',
#                                   'H1_hESC_3': 'INACTIVE',
#                                   'H9_1': 'INACTIVE',
#                                   'HCT116': 'INACTIVE',
#                                   'HSMM': 'INACTIVE',
#                                   'HUES48': 'INACTIVE',
#                                   'HUES6': 'INACTIVE',
#                                   'HUES64': 'INACTIVE',
#                                   'HUVEC': 'ACTIVE',
#                                   'HUVEC_prol_CB': 'INACTIVE',
#                                   'HeLa_S3': 'INACTIVE',
#                                   'HepG2': 'INACTIVE',
#                                   'K562': 'INACTIVE',
#                                   'M0_CB': 'INACTIVE',
#                                   'M0_VB': 'INACTIVE',
#                                   'M1_CB': 'INACTIVE',
#                                   'M1_VB': 'INACTIVE',
#                                   'M2_CB': 'INACTIVE',
#                                   'M2_VB': 'INACTIVE',
#                                   'MCF_7': 'INACTIVE',
#                                   'MM_1S': 'INACTIVE',
#                                   'MSC': 'INACTIVE',
#                                   'MSC_VB': 'INACTIVE',
#                                   'NHLF': 'INACTIVE',
#                                   'NK_PB': 'INACTIVE',
#                                   'NPC_1': 'INACTIVE',
#                                   'NPC_2': 'INACTIVE',
#                                   'NPC_3': 'INACTIVE',
#                                   'PC_3': 'INACTIVE',
#                                   'PC_9': 'INACTIVE',
#                                   'SK_N_': 'INACTIVE',
#                                   'T_PB': 'INACTIVE',
#                                   'Th17': 'INACTIVE',
#                                   'UCSF_4': 'INACTIVE',
#                                   'adrenal_gland': 'INACTIVE',
#                                   'aorta': 'INACTIVE',
#                                   'astrocyte': 'INACTIVE',
#                                   'bipolar_neuron': 'INACTIVE',
#                                   'brain_1': 'INACTIVE',
#                                   'brain_2': 'INACTIVE',
#                                   'cardiac_muscle': 'INACTIVE',
#                                   'dermal_fibroblast': 'INACTIVE',
#                                   'endocrine_pancreas': 'INACTIVE',
#                                   'endodermal': 'INACTIVE',
#                                   'eosinophil_VB': 'INACTIVE',
#                                   'esophagus': 'INACTIVE',
#                                   'foreskin_fibroblast_1': 'INACTIVE',
#                                   'foreskin_fibroblast_2': 'INACTIVE',
#                                   'foreskin_keratinocyte_2': 'INACTIVE',
#                                   'foreskin_melanocyte_1': 'INACTIVE',
#                                   'foreskin_melanocyte_2': 'INACTIVE',
#                                   'germinal_matrix': 'INACTIVE',
#                                   'heart': 'INACTIVE',
#                                   'hepatocyte': 'INACTIVE',
#                                   'iPS_15b': 'INACTIVE',
#                                   'iPS_20b': 'INACTIVE',
#                                   'iPS_DF_19_11': 'REPRESSED',
#                                   'iPS_DF_6_9': 'INACTIVE',
#                                   'keratinocyte': 'INACTIVE',
#                                   'kidney': 'INACTIVE',
#                                   'large_intestine': 'INACTIVE',
#                                   'left_ventricle': 'INACTIVE',
#                                   'leg_muscle': 'INACTIVE',
#                                   'lung_1': 'INACTIVE',
#                                   'lung_2': 'INACTIVE',
#                                   'mammary_epithelial_1': 'INACTIVE',
#                                   'mammary_epithelial_2': 'INACTIVE',
#                                   'monocyte_CB': 'INACTIVE',
#                                   'monocyte_VB': 'INACTIVE',
#                                   'myotube': 'INACTIVE',
#                                   'naive_B_VB': 'INACTIVE',
#                                   'neuron': 'INACTIVE',
#                                   'neurosphere_C': 'INACTIVE',
#                                   'neurosphere_GE': 'INACTIVE',
#                                   'neutro_myelocyte': 'INACTIVE',
#                                   'neutrophil_CB': 'INACTIVE',
#                                   'neutrophil_VB': 'INACTIVE',
#                                   'osteoblast': 'ACTIVE',
#                                   'ovary': 'INACTIVE',
#                                   'pancreas': 'INACTIVE',
#                                   'placenta': 'INACTIVE',
#                                   'psoas_muscle': 'INACTIVE',
#                                   'right_atrium': 'INACTIVE',
#                                   'right_ventricle': 'INACTIVE',
#                                   'sigmoid_colon': 'INACTIVE',
#                                   'small_intestine_1': 'INACTIVE',
#                                   'small_intestine_2': 'INACTIVE',
#                                   'spleen': 'INACTIVE',
#                                   'stomach_1': 'INACTIVE',
#                                   'stomach_2': 'INACTIVE',
#                                   'thymus_1': 'INACTIVE',
#                                   'thymus_2': 'INACTIVE',
#                                   'trophoblast': 'REPRESSED',
#                                   'trunk_muscle': 'INACTIVE'},
#                      'bound_end0': 55262400,
#                      'bound_end1': 55262400,
#                      'bound_start0': 55262200,
#                      'bound_start1': 55262201,
#                      'chrom': 7,
#                      'distance': 2686,
#                      'end0': 55262400,
#                      'end1': 55262400,
#                      'feature_type': 'regulatory',
#                      'feature_type_flags': {'is_motif': False,
#                                             'is_regulatory': True,
#                                             'is_repeat': False,
#                                             'is_transcript': False},
#                      'id': 'ENSR00002050860',
#                      'regulatory_subtype_flags': {'is_CTCFBS': False,
#                                                   'is_TFBS': False,
#                                                   'is_enhancer': True,
#                                                   'is_open_chromatin': False,
#                                                   'is_promoter': False,
#                                                   'is_promoter_flank': False},
#                      'start0': 55262200,
#                      'start1': 55262201}}
